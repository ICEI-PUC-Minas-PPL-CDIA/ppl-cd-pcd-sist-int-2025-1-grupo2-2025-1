# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import RFECV
import lightgbm as lgb
import optuna
import warnings
import re
import pickle
import time
import traceback

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=optuna.exceptions.ExperimentalWarning)

# Certifique-se de que a pasta para salvar visualizações existe
os.makedirs('visualizacoes_classificacao_salario_v7_rfecv', exist_ok=True)

def clean_col_name(col_name):
    """Limpa o nome da coluna para ser compatível com LightGBM."""
    original_input = col_name
    if isinstance(col_name, tuple):
        col_name = "_".join(str(item).strip() for item in col_name)
    elif not isinstance(col_name, str):
        col_name = str(col_name)
    col_name = re.sub(r'[^\w\s-]', '', col_name).strip()
    col_name = re.sub(r'[-\s]+', '_', col_name)
    col_name = re.sub(r"_+", "_", col_name)
    col_name = col_name.strip("_")
    if not col_name: return f"col_limpa_vazia_{hash(original_input)}"
    if col_name and col_name[0].isdigit(): col_name = "_" + col_name
    return col_name

def extract_salary_lower_bound(salary_range_str):
    """Extrai o limite inferior numérico de uma string de faixa salarial."""
    if pd.isna(salary_range_str): return np.nan
    s = str(salary_range_str).lower().replace('r$', '').replace('.', '').replace('/mês', '').strip()
    match_de_a = re.search(r'de\s*(\d+)\s*a\s*(\d+)', s)
    if match_de_a: return float(match_de_a.group(1))
    match_acima_de = re.search(r'acima de\s*(\d+)', s)
    if match_acima_de: return float(match_acima_de.group(1))
    match_menos_de = re.search(r'menos de\s*(\d+)', s)
    if match_menos_de: return 0
    match_so_numeros = re.findall(r'\d+', s)
    if match_so_numeros: return float(match_so_numeros[0])
    return np.nan

def map_uf_to_region(uf_series: pd.Series) -> pd.Series:
    """Mapeia siglas de UF para Regiões do Brasil."""
    mapa_regioes = {
        'AC': 'Norte', 'AL': 'Nordeste', 'AP': 'Norte', 'AM': 'Norte', 'BA': 'Nordeste',
        'CE': 'Nordeste', 'DF': 'Centro-Oeste', 'ES': 'Sudeste', 'GO': 'Centro-Oeste',
        'MA': 'Nordeste', 'MT': 'Centro-Oeste', 'MS': 'Centro-Oeste', 'MG': 'Sudeste',
        'PA': 'Norte', 'PB': 'Nordeste', 'PR': 'Sul', 'PE': 'Nordeste', 'PI': 'Nordeste',
        'RJ': 'Sudeste', 'RN': 'Nordeste', 'RS': 'Sul', 'RO': 'Norte', 'RR': 'Norte',
        'SC': 'Sul', 'SP': 'Sudeste', 'SE': 'Nordeste', 'TO': 'Norte'
    }
    uf_series_normalized = uf_series.astype(str).str.upper().str.strip()
    siglas_uf = list(mapa_regioes.keys())
    def extract_sigla(val):
        if val in siglas_uf: return val
        for sigla in siglas_uf:
            if f"({sigla})" in val or f" {sigla} " in val or val.endswith(f" {sigla}"): return sigla
        if "DISTRITO FEDERAL" in val: return "DF"
        if "SAO PAULO" in val: return "SP"
        if "RIO DE JANEIRO" in val: return "RJ"
        if "MINAS GERAIS" in val: return "MG"
        if "ESPIRITO SANTO" in val: return "ES"
        if "RIO GRANDE DO SUL" in val: return "RS"
        if "SANTA CATARINA" in val: return "SC"
        if "PARANA" in val: return "PR"
        return val
    uf_series_normalized = uf_series_normalized.apply(extract_sigla)
    mapped_series = uf_series_normalized.map(mapa_regioes)
    unmapped_count = mapped_series.isnull().sum()
    if unmapped_count > 0 and unmapped_count > len(uf_series) * 0.1:
        print(f"AVISO: {unmapped_count} de {len(uf_series)} valores de UF não foram mapeados para Região.")
        print(f"       Valores UF não mapeados (amostra): {uf_series_normalized[mapped_series.isnull()].unique()[:20]}")
    return mapped_series.fillna('Desconhecida')

def clean_experience_to_numeric(exp_val):
    """Converte strings de experiência para valores numéricos."""
    if pd.isna(exp_val):
        return np.nan
    s = str(exp_val).lower().strip()
    if 'menos de 1 ano' in s or 'menos de um ano' in s or '< 1 ano' in s:
        return 0.5
    if 'não tenho experiência' in s or 'sem experiência' in s:
        return 0
    numbers = re.findall(r'\d+\.?\d*', s)
    if numbers:
        return float(numbers[0])
    return np.nan

def train_classification_model_salary_range_v7_final(file_path, n_optuna_trials=100, optuna_timeout=1800, rfecv_folds=3, rfecv_step=1, rfecv_scoring='accuracy'):
    try:
        df_main = pd.read_excel(file_path)
        print(f"Base de dados carregada: {df_main.shape[0]} linhas, {df_main.shape[1]} colunas")

        original_columns = df_main.columns.tolist()
        df_main.columns = [clean_col_name(col) for col in original_columns]
        print("Nomes de colunas limpos.")

        col_mapping = {}
        target_mapped, faixa_etaria_mapped, genero_mapped, nivel_ensino_mapped = False, False, False, False
        tempo_experiencia_p2i_mapped, senioridade_p2g_mapped, uf_mora_p1i1_mapped, cargo_atual_p2f_mapped = False, False, False, False
        for col_idx, col_clean_name in enumerate(df_main.columns):
            if not target_mapped and ("P2_h" in col_clean_name or "faixa_salarial" in col_clean_name.lower()):
                col_mapping["target_original_salary_range"] = col_clean_name; target_mapped = True
            elif not tempo_experiencia_p2i_mapped and ("P2_i" in col_clean_name):
                col_mapping["tempo_experiencia_P2i"] = col_clean_name; tempo_experiencia_p2i_mapped = True
            elif not senioridade_p2g_mapped and ("P2_g" in col_clean_name):
                col_mapping["nivel_senioridade_P2g"] = col_clean_name; senioridade_p2g_mapped = True
            elif not uf_mora_p1i1_mapped and ("P1_i_1" in col_clean_name):
                col_mapping["uf_mora_P1i1"] = col_clean_name; uf_mora_p1i1_mapped = True
            elif not cargo_atual_p2f_mapped and ("P2_f" in col_clean_name):
                col_mapping["cargo_atual_P2f"] = col_clean_name; cargo_atual_p2f_mapped = True
            elif not faixa_etaria_mapped and ("P1_a_1" in col_clean_name or "faixa_etaria" in col_clean_name.lower()):
                col_mapping["faixa_etaria"] = col_clean_name; faixa_etaria_mapped = True
            elif not genero_mapped and ("P1_b" in col_clean_name or "genero" in col_clean_name.lower()):
                col_mapping["genero"] = col_clean_name; genero_mapped = True
            elif not nivel_ensino_mapped and ("P1_l" in col_clean_name or "nivel_ensino" in col_clean_name.lower()):
                col_mapping["nivel_ensino"] = col_clean_name; nivel_ensino_mapped = True

        target_col_agrupada_name = "faixa_salarial_agrupada_2cat_v7_rfecv_fixed_cut"
        col_mapping["target"] = target_col_agrupada_name

        print("\nMapeamento final de colunas:")
        for key, value in col_mapping.items():
            print(f"  {key}: {value}")

        required_cols_internal_for_features = [
            "faixa_etaria", "genero", "nivel_ensino",
            "tempo_experiencia_P2i", "nivel_senioridade_P2g",
            "uf_mora_P1i1", "cargo_atual_P2f"
        ]
        if "target_original_salary_range" not in col_mapping:
            print(f"Erro Crítico: Coluna original da faixa salarial não mapeada."); return None
        missing_feature_cols = [col_internal for col_internal in required_cols_internal_for_features if col_internal not in col_mapping]
        if missing_feature_cols:
            print(f"Erro Crítico: Features necessárias não mapeadas: {missing_feature_cols}."); return None

        if "tempo_experiencia_P2i" in col_mapping:
            exp_col_name = col_mapping["tempo_experiencia_P2i"]
            if exp_col_name in df_main.columns:
                print(f"Limpando e convertendo a coluna de experiência '{exp_col_name}' para numérico...")
                df_main[exp_col_name] = df_main[exp_col_name].apply(clean_experience_to_numeric)

        original_salary_col_name = col_mapping["target_original_salary_range"]
        df_main_processed = df_main.dropna(subset=[original_salary_col_name]).copy()
        if df_main_processed.empty: print(f"Erro: DataFrame vazio após NaNs na faixa salarial original."); return None

        df_main_processed['salary_numeric_lower_bound'] = df_main_processed[original_salary_col_name].apply(extract_salary_lower_bound)
        df_main_processed.dropna(subset=['salary_numeric_lower_bound'], inplace=True)

        if df_main_processed.empty:
            print(f"Erro: DataFrame vazio após remover NaNs de 'salary_numeric_lower_bound'."); return None

        # --- CRIAÇÃO DA VARIÁVEL ALVO COM 2 CATEGORIAS E PONTO DE CORTE FIXO ---
        salary_group_labels = ["Salário Baixo", "Salário Alto"]

        if df_main_processed.shape[0] < 2:
            print(f"Erro: Dados insuficientes ({df_main_processed.shape[0]}) para criar faixas."); return None

        min_salary = df_main_processed['salary_numeric_lower_bound'].min()
        max_salary = df_main_processed['salary_numeric_lower_bound'].max()

        if min_salary == max_salary:
            print(f"Aviso: Todos os valores de 'salary_numeric_lower_bound' são iguais ({min_salary}). Apenas uma categoria ('{salary_group_labels[0]}') será criada.")
            df_main_processed[target_col_agrupada_name] = salary_group_labels[0]
        else:
            # AJUSTE ESTE VALOR PARA CONTROLAR A DISTRIBUIÇÃO DAS CLASSES
            # Se "Salário Baixo" tiver muitas amostras, DIMINUA este valor.
            # Se "Salário Baixo" tiver poucas amostras, AUMENTE este valor.
            # Exemplos baseados no seu histograma: 7500, 8000, 9000.
            point_of_cut_fixed = 7500.0  # <-- PONTO DE CORTE AJUSTÁVEL

            print(f"Info: Usando ponto de corte fixo para salários: {point_of_cut_fixed:.2f}")
            print(f"       Salários <= {point_of_cut_fixed:.2f} serão '{salary_group_labels[0]}' (Salário Baixo)")
            print(f"       Salários >  {point_of_cut_fixed:.2f} serão '{salary_group_labels[1]}' (Salário Alto)")

            final_bins = []
            final_labels = []

            if point_of_cut_fixed <= min_salary:
                print(f"Aviso: Ponto de corte fixo ({point_of_cut_fixed:.2f}) é <= ao mínimo ({min_salary:.2f}). Todos os dados cairão em '{salary_group_labels[1]}'.")
                final_bins = [min_salary, max_salary]
                final_labels = [salary_group_labels[1]]
            elif point_of_cut_fixed >= max_salary:
                print(f"Aviso: Ponto de corte fixo ({point_of_cut_fixed:.2f}) é >= ao máximo ({max_salary:.2f}). Todos os dados cairão em '{salary_group_labels[0]}'.")
                final_bins = [min_salary, max_salary]
                final_labels = [salary_group_labels[0]]
            else:
                final_bins = [min_salary, point_of_cut_fixed, max_salary]
                final_labels = salary_group_labels

            unique_sorted_bins = sorted(list(set(final_bins)))

            if len(unique_sorted_bins) < 2:
                print(f"Erro crítico: Não foi possível definir pelo menos 2 bins únicos ({unique_sorted_bins}) com o ponto de corte fixo."); return None

            if len(unique_sorted_bins) == 2 and len(final_labels) == 2:
                print(f"Aviso: Ponto de corte fixo resultou em apenas 2 bins efetivos ({unique_sorted_bins}). Será criada apenas 1 categoria.")
                if point_of_cut_fixed <= min_salary + 1e-9:
                    final_labels = [salary_group_labels[1]]
                elif point_of_cut_fixed >= max_salary - 1e-9:
                    final_labels = [salary_group_labels[0]]
                else:
                    if (point_of_cut_fixed - min_salary) < (max_salary - point_of_cut_fixed):
                        final_labels = [salary_group_labels[1]]
                    else:
                        final_labels = [salary_group_labels[0]]

            bins_to_use = unique_sorted_bins
            labels_to_use = final_labels

            try:
                df_main_processed[target_col_agrupada_name] = pd.cut(
                    df_main_processed['salary_numeric_lower_bound'],
                    bins=bins_to_use,
                    labels=labels_to_use,
                    include_lowest=True,
                    duplicates='drop'
                )
            except Exception as e:
                print(f"Erro durante pd.cut com ponto de corte fixo: {e}")
                print(f"  Bins usados: {bins_to_use}, Labels usados: {labels_to_use}")
                print("  Tentando fallback para divisão pela mediana (pd.qcut)...")
                try:
                    df_main_processed[target_col_agrupada_name] = pd.qcut(
                        df_main_processed['salary_numeric_lower_bound'],
                        q=2, labels=salary_group_labels, duplicates='drop'
                    )
                    num_qcut_cats = len(df_main_processed[target_col_agrupada_name].cat.categories)
                    if num_qcut_cats < 2:
                        print("Fallback com qcut também resultou em menos de 2 categorias. Agrupando em uma única categoria.")
                        df_main_processed[target_col_agrupada_name] = salary_group_labels[0]
                except Exception as e_qcut_fallback:
                     print(f"Erro no fallback com pd.qcut: {e_qcut_fallback}. Não foi possível criar a variável alvo."); return None

        print(f"Nova coluna alvo '{target_col_agrupada_name}' criada. Contagens no DataFrame processado completo:\n{df_main_processed[target_col_agrupada_name].value_counts(dropna=False).sort_index()}")

        print("\nDiagnóstico da distribuição de 'salary_numeric_lower_bound':")
        print(df_main_processed['salary_numeric_lower_bound'].describe())
        plt.figure(figsize=(10,4))
        sns.histplot(df_main_processed['salary_numeric_lower_bound'], kde=True, bins=50)
        plt.title("Distribuição de 'salary_numeric_lower_bound'")
        plt.savefig('visualizacoes_classificacao_salario_v7_rfecv/distribuicao_salario_numerico.png')
        plt.show()
        plt.close()

        df_main_processed.dropna(subset=[target_col_agrupada_name], inplace=True)
        if df_main_processed.empty:
            print("Erro: DataFrame vazio após remover NaNs na coluna alvo agrupada. Verifique a criação das categorias."); return None
        print(f"Linhas após remover NaN na coluna alvo AGRUPADA: {df_main_processed.shape[0]}")
        # --- FIM DAS MODIFICAÇÕES NA VARIÁVEL ALVO ---

        feature_cols_to_use_initial = [col_mapping[col_internal] for col_internal in required_cols_internal_for_features if col_internal in col_mapping and col_mapping[col_internal] in df_main_processed.columns]
        X_initial = df_main_processed[feature_cols_to_use_initial].copy()

        uf_col_original_name_mapped = col_mapping.get("uf_mora_P1i1")
        if uf_col_original_name_mapped and uf_col_original_name_mapped in X_initial.columns:
            X_initial['Regiao_Mapeada'] = map_uf_to_region(X_initial[uf_col_original_name_mapped])
            X_initial.drop(columns=[uf_col_original_name_mapped], inplace=True)

        le = LabelEncoder()
        y_full = pd.Series(le.fit_transform(df_main_processed[target_col_agrupada_name]), index=df_main_processed.index)
        print(f"Alvo AGRUPADA '{target_col_agrupada_name}' codificada. Classes: {list(le.classes_)} -> {list(le.transform(le.classes_))}")

        if len(le.classes_) < 2:
            print(f"ERRO CRÍTICO: A variável alvo final tem menos de 2 classes ({len(le.classes_)}: {list(le.classes_)}). Não é possível treinar o modelo de classificação."); return None
        is_binary_classification = len(le.classes_) == 2

        if is_binary_classification:
            print("Classificação Binária Detectada.")
        else:
            print(f"Classificação Multiclasse Detectada ({len(le.classes_)} classes).")

        initial_feature_columns_after_region = X_initial.columns.tolist()
        print(f"Features para processamento inicial (antes RFECV): {initial_feature_columns_after_region}")

        numerical_features_initial = X_initial.select_dtypes(include=np.number).columns.tolist()
        categorical_features_initial = X_initial.select_dtypes(exclude=np.number).columns.tolist()

        print(f"Features numéricas identificadas: {numerical_features_initial}")
        print(f"Features categóricas identificadas: {categorical_features_initial}")

        for col in numerical_features_initial:
            if X_initial[col].isnull().sum() > 0:
                print(f"Imputando NaNs na feature numérica '{col}' com a mediana.")
                X_initial.loc[:, col] = X_initial[col].fillna(X_initial[col].median())

        outliers_indices = pd.Series(False, index=X_initial.index)
        if numerical_features_initial:
            print("Processando outliers para features numéricas...")
            for col in numerical_features_initial:
                Q1 = X_initial[col].quantile(0.25); Q3 = X_initial[col].quantile(0.75); IQR = Q3 - Q1
                lim_inf = Q1 - 1.5 * IQR; lim_sup = Q3 + 1.5 * IQR
                col_outliers = (X_initial[col] < lim_inf) | (X_initial[col] > lim_sup)
                if col_outliers.sum() > 0: print(f"  Feature '{col}': {col_outliers.sum()} outliers detectados.")
                outliers_indices = outliers_indices | col_outliers
            if outliers_indices.sum() > 0:
                print(f"Total de amostras com outliers: {outliers_indices.sum()}")
                X_initial = X_initial[~outliers_indices]; y_full = y_full[~outliers_indices]
                print(f"Shape de X_initial e y_full após remover outliers: {X_initial.shape}, {y_full.shape}")
                if X_initial.empty: print("ERRO: Todos os dados removidos como outliers."); return None
            else: print("Nenhum outlier encontrado em features numéricas.")
        else: print("Nenhuma feature numérica para checar outliers.")

        for col_name in categorical_features_initial:
            if col_name not in X_initial.columns: continue
            processed_series = X_initial[col_name].astype(str)
            missing_vals = ['nan', 'none', '<na>', '', 'missing', 'missing_category_value', 'missing_val_cat', 'null']
            temp_lower_stripped = processed_series.str.lower().str.strip()
            is_missing = temp_lower_stripped.isin(missing_vals) | X_initial[col_name].isnull()
            if is_missing.any():
                processed_series.loc[is_missing] = "Missing_Val_Cat"
            X_initial[col_name] = processed_series.astype("category")

        scaler_rfecv = StandardScaler()
        numerical_features_present_after_outliers = [col for col in numerical_features_initial if col in X_initial.columns]
        if numerical_features_present_after_outliers:
             X_initial.loc[:, numerical_features_present_after_outliers] = scaler_rfecv.fit_transform(X_initial[numerical_features_present_after_outliers])
             print(f"Features numéricas ({numerical_features_present_after_outliers}) em X_initial escalonadas.")
        else:
            print("Nenhuma feature numérica presente em X_initial para escalonar.")

        if y_full.nunique() < 2:
            print(f"ERRO CRÍTICO: A variável alvo final tem menos de 2 classes únicas ({y_full.nunique()}: {y_full.unique()}) após processamento. Não é possível treinar o modelo."); return None

        X_train_optuna, X_test, y_train_optuna, y_test = train_test_split(
            X_initial, y_full, test_size=0.25, random_state=42, stratify=y_full
        )
        print(f"Dados divididos em treino ({X_train_optuna.shape[0]}) e teste ({X_test.shape[0]})")

        print("\nIniciando Seleção de Features com RFECV...")
        start_time_rfecv = time.time()
        X_train_optuna_for_rfecv = X_train_optuna.copy()
        categorical_cols_for_rfecv_encoding = X_train_optuna_for_rfecv.select_dtypes(include='category').columns

        print(f"Colunas categóricas para codificação numérica no RFECV: {list(categorical_cols_for_rfecv_encoding)}")
        for col in categorical_cols_for_rfecv_encoding:
            X_train_optuna_for_rfecv[col] = X_train_optuna_for_rfecv[col].cat.codes

        estimator_rfecv = lgb.LGBMClassifier(random_state=42, n_jobs=-1, verbose=-1)
        cv_rfecv = StratifiedKFold(n_splits=rfecv_folds, shuffle=True, random_state=42)
        rfecv_selector = RFECV(estimator=estimator_rfecv, step=rfecv_step, cv=cv_rfecv,
                               scoring=rfecv_scoring, min_features_to_select=1, n_jobs=-1, verbose=1)

        rfecv_selector.fit(X_train_optuna_for_rfecv, y_train_optuna)

        end_time_rfecv = time.time()
        print(f"RFECV concluído em {(end_time_rfecv - start_time_rfecv):.2f} segundos.")
        print(f"Número ótimo de features selecionadas: {rfecv_selector.n_features_}")

        selected_features_names = X_train_optuna.columns[rfecv_selector.support_].tolist()
        print(f"Features selecionadas: {selected_features_names}")

        if not selected_features_names:
            print("ERRO CRÍTICO: Nenhuma feature selecionada pelo RFECV."); return None

        X_train_optuna_selected = X_train_optuna[selected_features_names].copy()
        X_test_selected = X_test[selected_features_names].copy()

        print(f"Features finais (selecionadas) para modelagem: {X_train_optuna_selected.columns.tolist()}")
        print(f"Dtypes de X_train_optuna_selected:\n{X_train_optuna_selected.dtypes}")

        min_class_count_cv = y_train_optuna.value_counts().min()
        n_cv_folds_optuna = min(5, min_class_count_cv) if min_class_count_cv >= 2 else 1
        if n_cv_folds_optuna < 2 and X_train_optuna_selected.shape[0] > 10:
             print(f"Aviso: Classe minoritária ({min_class_count_cv}) impede CV com mais de 1 fold. Optuna rodará sem CV interno robusto.")
             n_cv_folds_optuna = 1
        elif X_train_optuna_selected.shape[0] <=10:
             print("ERRO CRÍTICO: Dados de treino insuficientes após seleções/processamento."); return None
        if n_cv_folds_optuna == 0: n_cv_folds_optuna = 1

        def objective_optuna_cv(trial, X_data, y_data, n_cv_splits_internal):
            lgbm_objective = 'binary' if is_binary_classification else 'multiclass'
            lgbm_metric = 'binary_logloss' if is_binary_classification else 'multi_logloss'

            param_optuna = {
                'objective': lgbm_objective, 'metric': lgbm_metric,
                'n_estimators': trial.suggest_int('n_estimators', 200, 2000, step=100),
                'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.15, log=True),
                'num_leaves': trial.suggest_int('num_leaves', 20, 200, step=10),
                'max_depth': trial.suggest_int('max_depth', 3, 15),
                'min_child_samples': trial.suggest_int('min_child_samples', 5, 100, step=5),
                'subsample': trial.suggest_float('subsample', 0.5, 1.0, step=0.05),
                'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0, step=0.05),
                'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 20.0, log=True),
                'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 20.0, log=True),
                'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 0.7),
                'min_child_weight': trial.suggest_float('min_child_weight', 1e-4, 1.0, log=True),
                'random_state': 42, 'n_jobs': -1, 'verbose': -1, 'boosting_type': 'gbdt'
            }
            if not is_binary_classification:
                param_optuna['num_class'] = len(le.classes_)

            if n_cv_splits_internal >= 2:
                kf = StratifiedKFold(n_splits=n_cv_splits_internal, shuffle=True, random_state=trial.number)
                cv_accuracies = []
                for fold, (train_idx, val_idx) in enumerate(kf.split(X_data, y_data)):
                    X_fold_train, X_fold_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
                    y_fold_train, y_fold_val = y_data.iloc[train_idx], y_data.iloc[val_idx]
                    model = lgb.LGBMClassifier(**param_optuna)
                    model.fit(X_fold_train, y_fold_train,
                              eval_set=[(X_fold_val, y_fold_val)],
                              eval_metric=lgbm_metric,
                              callbacks=[lgb.early_stopping(20, verbose=False)])
                    preds = model.predict(X_fold_val)
                    cv_accuracies.append(accuracy_score(y_fold_val, preds))
                return np.mean(cv_accuracies)
            else:
                stratify_option = y_data if y_data.nunique() > 1 else None
                test_size_obj = 0.25 if len(y_data) >= 4 else (1/len(y_data) if len(y_data) > 1 else 0)
                if test_size_obj == 0 and len(y_data) == 1:
                    X_train_obj, X_val_obj, y_train_obj, y_val_obj = X_data, X_data.iloc[0:0], y_data, y_data.iloc[0:0]
                elif len(y_data) < 2 :
                     print("Aviso: Dados insuficientes para split em objective_optuna_cv, usando todo o conjunto para treino e avaliação.")
                     X_train_obj, X_val_obj, y_train_obj, y_val_obj = X_data, X_data.iloc[0:0], y_data, y_data.iloc[0:0]
                else:
                     X_train_obj, X_val_obj, y_train_obj, y_val_obj = train_test_split(X_data, y_data, test_size=test_size_obj, random_state=trial.number, stratify=stratify_option)

                model = lgb.LGBMClassifier(**param_optuna)
                model.fit(X_train_obj, y_train_obj,
                          eval_set=[(X_val_obj, y_val_obj)] if len(X_val_obj) > 0 else None,
                          eval_metric=lgbm_metric,
                          callbacks=[lgb.early_stopping(20, verbose=False)])
                preds = model.predict(X_val_obj if len(X_val_obj) > 0 else X_data)
                return accuracy_score(y_val_obj if len(X_val_obj) > 0 else y_data, preds)


        study_name = f'LGBM_Salary_Clf_Optuna_CV_v7_final_rfecv_trials{n_optuna_trials}'
        study = optuna.create_study(direction='maximize', study_name=study_name)
        if n_cv_folds_optuna >=2:
            print(f"\nIniciando otimização com Optuna ({n_optuna_trials} trials) e {n_cv_folds_optuna}-Fold CV...")
        else:
            print(f"\nIniciando otimização com Optuna ({n_optuna_trials} trials) e validação simples (holdout)...")

        study.optimize(lambda trial: objective_optuna_cv(trial, X_train_optuna_selected, y_train_optuna, n_cv_splits_internal=n_cv_folds_optuna),
                       n_trials=n_optuna_trials, timeout=optuna_timeout)

        print("\nOtimização com Optuna concluída!")
        best_optuna_score = study.best_trial.value if study.best_trial else -1.0
        print(f"Melhor Acurácia Média no CV/Val do Optuna: {best_optuna_score:.4f}")
        best_params_optuna = study.best_trial.params if study.best_trial else {}
        print(f"Melhores hiperparâmetros (Optuna): {best_params_optuna}")

        X_train_final, X_val_internal, y_train_final, y_val_internal = train_test_split(
            X_train_optuna_selected, y_train_optuna, test_size=0.20, random_state=42, stratify=y_train_optuna
        )

        lgbm_final_objective = 'binary' if is_binary_classification else 'multiclass'
        lgbm_final_metric = 'binary_logloss' if is_binary_classification else 'multi_logloss'

        best_lgbm = lgb.LGBMClassifier(
            objective=lgbm_final_objective, metric=lgbm_final_metric,
            random_state=42, n_jobs=-1, verbose=-1, **best_params_optuna
        )
        if not is_binary_classification:
            best_lgbm.set_params(num_class=len(le.classes_))

        print("Treinando o modelo final com early stopping...")
        best_lgbm.fit(X_train_final, y_train_final, eval_set=[(X_val_internal, y_val_internal)],
                      eval_metric=lgbm_final_metric,
                      callbacks=[lgb.early_stopping(25, verbose=False)])

        final_model_iter = best_lgbm.best_iteration_ if hasattr(best_lgbm, 'best_iteration_') and best_lgbm.best_iteration_ is not None else best_params_optuna.get('n_estimators')
        print(f"Modelo final treinado. Número de árvores: {final_model_iter}")

        y_pred_train_final = best_lgbm.predict(X_train_final)
        accuracy_train_final = accuracy_score(y_train_final, y_pred_train_final)
        print(f"Acurácia do Modelo Final no seu Conjunto de Treinamento (X_train_final): {accuracy_train_final:.4f}")

        print("\nAvaliando o modelo final no conjunto de teste (com features selecionadas)...")
        y_pred_test = best_lgbm.predict(X_test_selected)
        y_pred_proba_all_classes_test = best_lgbm.predict_proba(X_test_selected)

        accuracy_test = accuracy_score(y_test, y_pred_test)
        f1_test = f1_score(y_test, y_pred_test, average='weighted')

        report_dict_test = classification_report(y_test, y_pred_test, target_names=le.classes_, zero_division=0, output_dict=True)
        report_str_test = classification_report(y_test, y_pred_test, target_names=le.classes_, zero_division=0)

        conf_matrix_test = confusion_matrix(y_test, y_pred_test)
        roc_auc_test = 0.0
        if len(le.classes_) >= 2:
            if is_binary_classification:
                roc_auc_test = roc_auc_score(y_test, y_pred_proba_all_classes_test[:, 1]) if y_pred_proba_all_classes_test.shape[1] == 2 else 0.0
            else:
                 roc_auc_test = roc_auc_score(y_test, y_pred_proba_all_classes_test, multi_class='ovr', average='weighted')

        macro_avg_precision_test = report_dict_test.get('macro avg', {}).get('precision', 0.0)
        weighted_avg_precision_test = report_dict_test.get('weighted avg', {}).get('precision', 0.0)

        print(f"\n--- Resultados da Avaliação no CONJUNTO DE TESTE (v7 - Final - {'Binário' if is_binary_classification else 'Multiclasse'}) ---")
        print(f"Acurácia no Teste: {accuracy_test:.4f}")
        print(f"Precisão Média (Macro Avg) no Teste: {macro_avg_precision_test:.4f}")
        print(f"Precisão Média (Weighted Avg) no Teste: {weighted_avg_precision_test:.4f}")
        print(f"F1-Score (Ponderado) no Teste: {f1_test:.4f}")
        print(f"ROC AUC ({'Binário' if is_binary_classification else 'Ponderado OVR'}) no Teste: {roc_auc_test:.4f}")
        print("\nRelatório de Classificação (Teste):\n", report_str_test)

        conf_matrix_normalized_test = None
        if len(le.classes_) > 1 and conf_matrix_test.sum(axis=1, keepdims=True).all() > 0 :
            conf_matrix_normalized_test = conf_matrix_test.astype('float') / conf_matrix_test.sum(axis=1, keepdims=True)
            plt.figure(figsize=(max(8, len(le.classes_)*1.5), max(6, len(le.classes_)*1.2)))
            sns.heatmap(conf_matrix_normalized_test, annot=True, fmt=".2%", cmap="Blues", xticklabels=le.classes_, yticklabels=le.classes_)
            plt.title(f'Matriz de Confusão Normalizada (Teste - v7 Final - {"Binário" if is_binary_classification else "Multiclasse"})')
            plt.ylabel('Classe Verdadeira'); plt.xlabel('Classe Prevista')
            plt.savefig('visualizacoes_classificacao_salario_v7_rfecv/matriz_confusao_norm_v7_final_teste.png')
            plt.show()
            plt.close()
        elif len(le.classes_) > 1:
            print("Aviso: Não foi possível normalizar a matriz de confusão (alguma classe pode não ter amostras verdadeiras no conjunto de teste).")

        feature_importance_df = None
        if hasattr(best_lgbm, 'feature_importances_') and X_train_final.shape[1] > 0:
            feature_importance_df = pd.DataFrame({'feature': X_train_final.columns, 'importance': best_lgbm.feature_importances_}).sort_values(by='importance', ascending=False)
            print("\nImportância das Features (após RFECV, modelo Optuna com ES):\n", feature_importance_df.head(min(15, len(X_train_final.columns))))
            plt.figure(figsize=(10, max(6, len(feature_importance_df.head(min(15, len(X_train_final.columns)))) * 0.5)))
            sns.barplot(x='importance', y='feature', data=feature_importance_df.head(min(15, len(X_train_final.columns))))
            plt.title(f'Top {min(15, len(X_train_final.columns))} Features (v7 Final - {"Binário" if is_binary_classification else "Multiclasse"})')
            plt.tight_layout()
            plt.savefig('visualizacoes_classificacao_salario_v7_rfecv/feature_importance_v7_final.png')
            plt.show()
            plt.close()

        results_filename_txt = "modelo_classificacao_faixa_salarial_v7_final_rfecv_resultados.txt"
        model_filename_pkl = 'modelo_lgbm_classificacao_faixa_salarial_v7_final_rfecv.pkl'
        with open(results_filename_txt, "w", encoding="utf-8") as f:
            f.write(f"Modelo: LightGBM (Optuna, RFECV, ES) para classificação de Faixa Salarial (v7 Final - {'Binário' if is_binary_classification else f'Multiclasse ({len(le.classes_)} classes)'})\\n")
            f.write(f"Coluna Alvo Agrupada: {target_col_agrupada_name} com classes: {list(le.classes_)}\\n")
            f.write(f"Features Iniciais para processamento ({len(initial_feature_columns_after_region)}): {initial_feature_columns_after_region}\\n")
            f.write(f"Features Selecionadas pelo RFECV ({rfecv_selector.n_features_}): {selected_features_names}\\n\\n")
            f.write(f"Melhores parâmetros (Optuna): {best_params_optuna}\\n")
            f.write(f"Número de árvores usadas pelo modelo final: {final_model_iter}\\n\\n")
            f.write(f"Acurácia Média CV/Val (Optuna): {best_optuna_score:.4f}\\n")
            f.write(f"Acurácia do Modelo Final no seu Conjunto de Treinamento (X_train_final): {accuracy_train_final:.4f}\\n\\n")
            f.write(f"RESULTADOS NO CONJUNTO DE TESTE:\\n")
            f.write(f"  Acurácia no Teste: {accuracy_test:.4f}\\n")
            f.write(f"  Precisão Média (Macro Avg) no Teste: {macro_avg_precision_test:.4f}\\n")
            f.write(f"  Precisão Média (Weighted Avg) no Teste: {weighted_avg_precision_test:.4f}\\n")
            f.write(f"  F1-Score (Ponderado) no Teste: {f1_test:.4f}\\n")
            f.write(f"  ROC AUC ({'Binário' if is_binary_classification else 'Ponderado OVR'}) no Teste: {roc_auc_test:.4f}\\n\\n")
            f.write("Relatório de Classificação (Teste):\\n"); f.write(report_str_test)
            f.write("\nMatriz de Confusão (Teste - Absoluta):\\n"); f.write(str(conf_matrix_test))
            if feature_importance_df is not None:
                 f.write("\n\nImportância das Features:\\n"); f.write(feature_importance_df.to_string())

        with open(model_filename_pkl, 'wb') as f: pickle.dump({
            'model': best_lgbm, 'label_encoder': le, 'selected_features': selected_features_names,
            'scaler_rfecv_fitted_on_initial_numerical': scaler_rfecv,
            'original_columns_for_scaler': numerical_features_present_after_outliers,
            'is_binary_classification': is_binary_classification,
            'target_col_name': target_col_agrupada_name
        }, f)
        print(f"Modelo e metadados salvos em {model_filename_pkl}")

        return {
            'accuracy_train_final': accuracy_train_final,
            'optuna_best_cv_score': best_optuna_score,
            'accuracy_test': accuracy_test,
            'macro_avg_precision_test': macro_avg_precision_test,
            'weighted_avg_precision_test': weighted_avg_precision_test,
            'f1_score_test': f1_test,
            'roc_auc_test': roc_auc_test,
            'selected_features_count': rfecv_selector.n_features_,
            'selected_features_names': selected_features_names,
            'best_params': best_params_optuna, 'model_object_path': model_filename_pkl,
            'final_model_best_iteration': final_model_iter,
            'classification_report_dict_test': report_dict_test,
            'is_binary_classification': is_binary_classification,
            'target_classes': list(le.classes_)
        }
    except Exception as e:
        print(f"Ocorreu um erro inesperado na função principal: {e}")
        traceback.print_exc(); return None

if __name__ == "__main__":
    file_path = "Main_database (2).xlsx" # CONFIRME O NOME DO ARQUIVO
    if os.path.exists(file_path):
        results_v7_final = train_classification_model_salary_range_v7_final(
            file_path,
            n_optuna_trials=100,
            optuna_timeout=1800,
            rfecv_folds=3,
            rfecv_scoring='accuracy'
        )
        if results_v7_final:
            print("\n\n--- Resumo Final da Execução (v7 - Final com RFECV, Optuna, ES) ---")
            classification_type = "Binário" if results_v7_final.get('is_binary_classification', False) else f"Multiclasse ({len(results_v7_final.get('target_classes', []))} classes)"
            print(f"Tipo de Classificação: {classification_type}, Classes: {results_v7_final.get('target_classes', 'N/A')}")
            print(f"Acurácia do Modelo Final no Treinamento (X_train_final): {results_v7_final['accuracy_train_final']:.4f}")
            print(f"Acurácia Média CV/Val (Optuna): {results_v7_final['optuna_best_cv_score']:.4f}")
            print(f"-------------------------------------------------------------")
            print(f"Acurácia no Teste: {results_v7_final['accuracy_test']:.4f}")
            print(f"Precisão Média (Macro Avg) no Teste: {results_v7_final['macro_avg_precision_test']:.4f}")
            print(f"Precisão Média (Weighted Avg) no Teste: {results_v7_final['weighted_avg_precision_test']:.4f}")
            print(f"F1-Score (Ponderado) no Teste: {results_v7_final['f1_score_test']:.4f}")
            roc_auc_label = "Binário" if results_v7_final.get('is_binary_classification', False) else "Ponderado OVR"
            print(f"ROC AUC ({roc_auc_label}) no Teste: {results_v7_final['roc_auc_test']:.4f}")
            print(f"-------------------------------------------------------------")
            print(f"Features Selecionadas pelo RFECV: {results_v7_final['selected_features_count']} -> {results_v7_final['selected_features_names']}")
            print(f"Melhores Parâmetros (Optuna): {results_v7_final['best_params']}")
            print(f"Número de Árvores no Modelo Final: {results_v7_final['final_model_best_iteration']}")
            print(f"Modelo e resultados detalhados salvos em arquivos.")
    else:
        print(f"ERRO: Arquivo '{file_path}' não encontrado.")
# Out:
# Base de dados carregada: 5293 linhas, 399 colunas
# Nomes de colunas limpos.
#
# Mapeamento final de colunas:
#   faixa_etaria: P1_a_1
#   genero: P1_b
#   uf_mora_P1i1: P1_i_1_uf_onde_mora
#   nivel_ensino: P1_l
#   cargo_atual_P2f: P2_f_Cargo_Atual
#   nivel_senioridade_P2g: P2_g_Nivel
#   target_original_salary_range: P2_h
#   tempo_experiencia_P2i: P2_i
#   target: faixa_salarial_agrupada_2cat_v7_rfecv_fixed_cut
# Limpando e convertendo a coluna de experiência 'P2_i' para numérico...
# Info: Usando ponto de corte fixo para salários: 7500.00
#        Salários <= 7500.00 serão 'Salário Baixo' (Salário Baixo)
#        Salários >  7500.00 serão 'Salário Alto' (Salário Alto)
# Nova coluna alvo 'faixa_salarial_agrupada_2cat_v7_rfecv_fixed_cut' criada. Contagens no DataFrame processado completo:
# faixa_salarial_agrupada_2cat_v7_rfecv_fixed_cut
# Salário Baixo    2268
# Salário Alto     2485
# Name: count, dtype: int64
#
# Diagnóstico da distribuição de 'salary_numeric_lower_bound':
# count     4753.000000
# mean      8935.371976
# std       7308.444315
# min          0.000000
# 25%       4001.000000
# 50%       8001.000000
# 75%      12001.000000
# max      40001.000000
# Name: salary_numeric_lower_bound, dtype: float64
# Linhas após remover NaN na coluna alvo AGRUPADA: 4753
# Alvo AGRUPADA 'faixa_salarial_agrupada_2cat_v7_rfecv_fixed_cut' codificada. Classes: ['Salário Alto', 'Salário Baixo'] -> [0, 1]
# Classificação Binária Detectada.
# Features para processamento inicial (antes RFECV): ['P1_a_1', 'P1_b', 'P1_l', 'P2_i', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Features numéricas identificadas: ['P2_i']
# Features categóricas identificadas: ['P1_a_1', 'P1_b', 'P1_l', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Processando outliers para features numéricas...
# Nenhum outlier encontrado em features numéricas.
# Features numéricas (['P2_i']) em X_initial escalonadas.
# Dados divididos em treino (3564) e teste (1189)
#
# Iniciando Seleção de Features com RFECV...
# Colunas categóricas para codificação numérica no RFECV: ['P1_a_1', 'P1_b', 'P1_l', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Fitting estimator with 7 features.
# [I 2025-05-12 23:43:32,020] A new study created in memory with name: LGBM_Salary_Clf_Optuna_CV_v7_final_rfecv_trials100
# RFECV concluído em 16.36 segundos.
# Número ótimo de features selecionadas: 6
# Features selecionadas: ['P1_a_1', 'P1_l', 'P2_i', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Features finais (selecionadas) para modelagem: ['P1_a_1', 'P1_l', 'P2_i', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Dtypes de X_train_optuna_selected:
# P1_a_1              category
# P1_l                category
# P2_i                 float64
# P2_g_Nivel          category
# P2_f_Cargo_Atual    category
# Regiao_Mapeada      category
# dtype: object
#
# Iniciando otimização com Optuna (100 trials) e 5-Fold CV...
# [I 2025-05-12 23:43:32,871] Trial 0 finished with value: 0.8423101470286966 and parameters: {'n_estimators': 300, 'learning_rate': 0.014945213131574356, 'num_leaves': 40, 'max_depth': 9, 'min_child_samples': 85, 'subsample': 0.9, 'colsample_bytree': 0.75, 'reg_alpha': 0.09554427400886083, 'reg_lambda': 0.02113420035168051, 'min_split_gain': 0.6192744715468355, 'min_child_weight': 0.5724987503496866}. Best is trial 0 with value: 0.8423101470286966.
# [I 2025-05-12 23:43:33,582] Trial 1 finished with value: 0.8448295696298281 and parameters: {'n_estimators': 200, 'learning_rate': 0.03025775020704424, 'num_leaves': 150, 'max_depth': 8, 'min_child_samples': 5, 'subsample': 0.95, 'colsample_bytree': 0.65, 'reg_alpha': 0.0022558795940209853, 'reg_lambda': 3.0404251658741774, 'min_split_gain': 0.0901189115959854, 'min_child_weight': 0.5538604031115043}. Best is trial 1 with value: 0.8448295696298281.
# [I 2025-05-12 23:43:38,474] Trial 2 finished with value: 0.8465244181099012 and parameters: {'n_estimators': 1800, 'learning_rate': 0.006151223061132449, 'num_leaves': 110, 'max_depth': 15, 'min_child_samples': 70, 'subsample': 0.95, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 3.047855118711719, 'reg_lambda': 0.001238699783919317, 'min_split_gain': 0.6864085104952417, 'min_child_weight': 0.011530701207434867}. Best is trial 2 with value: 0.8465244181099012.
# [I 2025-05-12 23:43:39,433] Trial 3 finished with value: 0.843995146319555 and parameters: {'n_estimators': 400, 'learning_rate': 0.02157653078876226, 'num_leaves': 130, 'max_depth': 4, 'min_child_samples': 60, 'subsample': 0.75, 'colsample_bytree': 0.5, 'reg_alpha': 0.010633135110854416, 'reg_lambda': 0.008727442572029937, 'min_split_gain': 0.3291583101898602, 'min_child_weight': 0.04138624253450462}. Best is trial 2 with value: 0.8465244181099012.
# [I 2025-05-12 23:43:40,501] Trial 4 finished with value: 0.8473659328364089 and parameters: {'n_estimators': 600, 'learning_rate': 0.024343121487897097, 'num_leaves': 110, 'max_depth': 11, 'min_child_samples': 65, 'subsample': 0.95, 'colsample_bytree': 1.0, 'reg_alpha': 0.7373469205830534, 'reg_lambda': 9.923933195503043, 'min_split_gain': 0.41240882285664493, 'min_child_weight': 0.12201333580957094}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:41,102] Trial 5 finished with value: 0.8392234111287958 and parameters: {'n_estimators': 300, 'learning_rate': 0.017553181815228636, 'num_leaves': 100, 'max_depth': 9, 'min_child_samples': 15, 'subsample': 0.7, 'colsample_bytree': 0.4, 'reg_alpha': 2.800887569035051, 'reg_lambda': 0.4730535297178446, 'min_split_gain': 0.6991676328218817, 'min_child_weight': 0.00011489440988161024}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:41,546] Trial 6 finished with value: 0.8439908126763005 and parameters: {'n_estimators': 500, 'learning_rate': 0.06313506378746037, 'num_leaves': 200, 'max_depth': 8, 'min_child_samples': 50, 'subsample': 0.65, 'colsample_bytree': 1.0, 'reg_alpha': 0.028435707316095325, 'reg_lambda': 0.0011159261221073006, 'min_split_gain': 0.5741700205553973, 'min_child_weight': 0.7226518803192101}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:41,936] Trial 7 finished with value: 0.8428715508139369 and parameters: {'n_estimators': 400, 'learning_rate': 0.06269484186612267, 'num_leaves': 50, 'max_depth': 5, 'min_child_samples': 10, 'subsample': 0.6, 'colsample_bytree': 0.5, 'reg_alpha': 6.247633260802904, 'reg_lambda': 0.018244588662492386, 'min_split_gain': 0.5308084177360847, 'min_child_weight': 0.08479481320057665}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:42,478] Trial 8 finished with value: 0.8403466126668452 and parameters: {'n_estimators': 300, 'learning_rate': 0.04595915499610669, 'num_leaves': 70, 'max_depth': 14, 'min_child_samples': 85, 'subsample': 0.75, 'colsample_bytree': 0.9500000000000001, 'reg_alpha': 0.00797811927012724, 'reg_lambda': 0.5913924431852708, 'min_split_gain': 0.4875233149892363, 'min_child_weight': 0.006162169150861938}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:45,364] Trial 9 finished with value: 0.8437154293458562 and parameters: {'n_estimators': 2000, 'learning_rate': 0.005608470194942635, 'num_leaves': 120, 'max_depth': 8, 'min_child_samples': 10, 'subsample': 0.6, 'colsample_bytree': 0.75, 'reg_alpha': 14.934741464624974, 'reg_lambda': 0.0017722041356521329, 'min_split_gain': 0.2580351183069602, 'min_child_weight': 0.9338789693450412}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:45,869] Trial 10 finished with value: 0.843714641410719 and parameters: {'n_estimators': 1000, 'learning_rate': 0.10990394176786338, 'num_leaves': 170, 'max_depth': 13, 'min_child_samples': 40, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.8500000000000001, 'reg_alpha': 0.4452563737355771, 'reg_lambda': 17.425263949482197, 'min_split_gain': 0.1447827293899416, 'min_child_weight': 0.0005628981329605795}. Best is trial 4 with value: 0.8473659328364089.
# [I 2025-05-12 23:43:53,937] Trial 11 finished with value: 0.8481999621791134 and parameters: {'n_estimators': 1900, 'learning_rate': 0.006164169896964576, 'num_leaves': 90, 'max_depth': 12, 'min_child_samples': 70, 'subsample': 1.0, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.9605497617114884, 'reg_lambda': 17.86817718603614, 'min_split_gain': 0.4269572962063235, 'min_child_weight': 0.00348932154096441}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:43:56,087] Trial 12 finished with value: 0.8437150353782877 and parameters: {'n_estimators': 1400, 'learning_rate': 0.0103296943955484, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 95, 'subsample': 1.0, 'colsample_bytree': 0.8500000000000001, 'reg_alpha': 0.38629482154845446, 'reg_lambda': 15.588628575262172, 'min_split_gain': 0.42655550220673516, 'min_child_weight': 0.003217340856653381}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:43:58,030] Trial 13 finished with value: 0.8456868430590794 and parameters: {'n_estimators': 900, 'learning_rate': 0.009923724168655803, 'num_leaves': 20, 'max_depth': 12, 'min_child_samples': 70, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.55, 'reg_alpha': 0.6352487528965611, 'reg_lambda': 3.42462275648837, 'min_split_gain': 0.39867440585457353, 'min_child_weight': 0.06786830380284825}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:43:58,800] Trial 14 finished with value: 0.8437181871188363 and parameters: {'n_estimators': 1400, 'learning_rate': 0.034804192107464806, 'num_leaves': 80, 'max_depth': 11, 'min_child_samples': 45, 'subsample': 1.0, 'colsample_bytree': 0.8500000000000001, 'reg_alpha': 1.2535773023212549, 'reg_lambda': 3.252754749883262, 'min_split_gain': 0.2313429419776628, 'min_child_weight': 0.0020940688851386956}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:43:59,112] Trial 15 finished with value: 0.8468037411160314 and parameters: {'n_estimators': 700, 'learning_rate': 0.13179917249613768, 'num_leaves': 150, 'max_depth': 11, 'min_child_samples': 65, 'subsample': 0.9, 'colsample_bytree': 0.7000000000000001, 'reg_alpha': 0.14242219926780492, 'reg_lambda': 0.15193137947066337, 'min_split_gain': 0.34694186622962475, 'min_child_weight': 0.019285590941304952}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:03,524] Trial 16 finished with value: 0.842315662574657 and parameters: {'n_estimators': 1300, 'learning_rate': 0.009894607039767874, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 35, 'subsample': 0.5, 'colsample_bytree': 0.4, 'reg_alpha': 0.11373991036747826, 'reg_lambda': 5.638351828033405, 'min_split_gain': 0.46371542166494106, 'min_child_weight': 0.17677294331177618}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:05,029] Trial 17 finished with value: 0.8428723387490742 and parameters: {'n_estimators': 1700, 'learning_rate': 0.013100825182506673, 'num_leaves': 140, 'max_depth': 11, 'min_child_samples': 30, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.9500000000000001, 'reg_alpha': 1.324734486039061, 'reg_lambda': 0.8680072415366908, 'min_split_gain': 0.26814473799471655, 'min_child_weight': 0.0007911647590987939}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:06,876] Trial 18 finished with value: 0.8465220543044897 and parameters: {'n_estimators': 800, 'learning_rate': 0.007476869244035397, 'num_leaves': 170, 'max_depth': 15, 'min_child_samples': 80, 'subsample': 1.0, 'colsample_bytree': 0.75, 'reg_alpha': 15.46288994823369, 'reg_lambda': 10.09586238532079, 'min_split_gain': 0.02950319430373277, 'min_child_weight': 0.196472632899642}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:07,790] Trial 19 finished with value: 0.8439923885465749 and parameters: {'n_estimators': 600, 'learning_rate': 0.0248074379088728, 'num_leaves': 60, 'max_depth': 13, 'min_child_samples': 100, 'subsample': 0.8, 'colsample_bytree': 0.65, 'reg_alpha': 0.04548754852746085, 'reg_lambda': 1.1804368566938106, 'min_split_gain': 0.1721325622381913, 'min_child_weight': 0.023320265157953664}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:08,209] Trial 20 finished with value: 0.8445589139102069 and parameters: {'n_estimators': 1200, 'learning_rate': 0.08482861445216082, 'num_leaves': 90, 'max_depth': 10, 'min_child_samples': 55, 'subsample': 0.95, 'colsample_bytree': 0.5, 'reg_alpha': 0.25710789136131296, 'reg_lambda': 0.1397983903952963, 'min_split_gain': 0.38606045741961853, 'min_child_weight': 0.0009013056350480388}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:08,523] Trial 21 finished with value: 0.8448339032730825 and parameters: {'n_estimators': 700, 'learning_rate': 0.134859846268781, 'num_leaves': 150, 'max_depth': 11, 'min_child_samples': 60, 'subsample': 0.9, 'colsample_bytree': 0.65, 'reg_alpha': 1.2540400819741246, 'reg_lambda': 0.12671621685401274, 'min_split_gain': 0.3192900454519507, 'min_child_weight': 0.019565330603418505}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:09,175] Trial 22 finished with value: 0.8448374489811998 and parameters: {'n_estimators': 700, 'learning_rate': 0.04584198955122121, 'num_leaves': 170, 'max_depth': 13, 'min_child_samples': 70, 'subsample': 0.9, 'colsample_bytree': 0.8, 'reg_alpha': 0.20497957695239225, 'reg_lambda': 0.04539831484430698, 'min_split_gain': 0.33336939481924416, 'min_child_weight': 0.005222372683342377}. Best is trial 11 with value: 0.8481999621791134.
# [I 2025-05-12 23:44:09,475] Trial 23 finished with value: 0.8490458105488756 and parameters: {'n_estimators': 1100, 'learning_rate': 0.14511576233493734, 'num_leaves': 120, 'max_depth': 10, 'min_child_samples': 75, 'subsample': 0.95, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.05325586891862114, 'reg_lambda': 0.2670765131671632, 'min_split_gain': 0.4708823457662362, 'min_child_weight': 0.15864833049433302}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:10,186] Trial 24 finished with value: 0.8459559229084261 and parameters: {'n_estimators': 1600, 'learning_rate': 0.04024779973947832, 'num_leaves': 120, 'max_depth': 10, 'min_child_samples': 80, 'subsample': 1.0, 'colsample_bytree': 0.55, 'reg_alpha': 0.03142902698947457, 'reg_lambda': 7.646964588482801, 'min_split_gain': 0.49369106501243054, 'min_child_weight': 0.23063980528076317}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:10,610] Trial 25 finished with value: 0.8425961674834926 and parameters: {'n_estimators': 1100, 'learning_rate': 0.0686553543862108, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 75, 'subsample': 0.95, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.06492467412135396, 'reg_lambda': 1.7423987624464654, 'min_split_gain': 0.583983008528907, 'min_child_weight': 0.08183349207246067}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:11,753] Trial 26 finished with value: 0.846243125265928 and parameters: {'n_estimators': 1500, 'learning_rate': 0.019038546459467287, 'num_leaves': 120, 'max_depth': 10, 'min_child_samples': 95, 'subsample': 0.8, 'colsample_bytree': 0.45, 'reg_alpha': 0.742416322445944, 'reg_lambda': 0.37240508329821154, 'min_split_gain': 0.4451225472826318, 'min_child_weight': 0.24441703797641556}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:12,171] Trial 27 finished with value: 0.8465204784342154 and parameters: {'n_estimators': 2000, 'learning_rate': 0.09236612641297447, 'num_leaves': 130, 'max_depth': 12, 'min_child_samples': 55, 'subsample': 0.95, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.007720724595384975, 'reg_lambda': 1.988057986434042, 'min_split_gain': 0.39292931387315166, 'min_child_weight': 0.04019048470801383}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:16,897] Trial 28 finished with value: 0.8462411554280852 and parameters: {'n_estimators': 1000, 'learning_rate': 0.005009532992530546, 'num_leaves': 80, 'max_depth': 9, 'min_child_samples': 90, 'subsample': 0.8, 'colsample_bytree': 0.7000000000000001, 'reg_alpha': 2.7655704917116974, 'reg_lambda': 0.003241867586445194, 'min_split_gain': 0.5460008113950389, 'min_child_weight': 0.0018021830144812024}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:18,098] Trial 29 finished with value: 0.8442768331310967 and parameters: {'n_estimators': 1800, 'learning_rate': 0.014756429548517422, 'num_leaves': 30, 'max_depth': 7, 'min_child_samples': 80, 'subsample': 0.9, 'colsample_bytree': 0.55, 'reg_alpha': 5.419701894305228, 'reg_lambda': 0.0501909916628745, 'min_split_gain': 0.6188436766536861, 'min_child_weight': 0.4034785183239}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:19,658] Trial 30 finished with value: 0.8439947523519864 and parameters: {'n_estimators': 1200, 'learning_rate': 0.01233863517131141, 'num_leaves': 50, 'max_depth': 3, 'min_child_samples': 25, 'subsample': 1.0, 'colsample_bytree': 0.8, 'reg_alpha': 0.01616037497146871, 'reg_lambda': 5.6368551753022, 'min_split_gain': 0.502065805473964, 'min_child_weight': 0.0002631405643020922}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:20,052] Trial 31 finished with value: 0.8465212663693524 and parameters: {'n_estimators': 800, 'learning_rate': 0.09748920406958217, 'num_leaves': 150, 'max_depth': 11, 'min_child_samples': 65, 'subsample': 0.9, 'colsample_bytree': 0.7000000000000001, 'reg_alpha': 0.13105869318874494, 'reg_lambda': 0.29608902509702173, 'min_split_gain': 0.2924989516112546, 'min_child_weight': 0.012552156049478184}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:20,416] Trial 32 finished with value: 0.8445569440723639 and parameters: {'n_estimators': 600, 'learning_rate': 0.11336889819146384, 'num_leaves': 140, 'max_depth': 10, 'min_child_samples': 65, 'subsample': 0.95, 'colsample_bytree': 0.65, 'reg_alpha': 0.07874498103326881, 'reg_lambda': 0.07160348624699295, 'min_split_gain': 0.3593919179776336, 'min_child_weight': 0.11963647510216843}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:20,723] Trial 33 finished with value: 0.843154813495753 and parameters: {'n_estimators': 500, 'learning_rate': 0.14701666213330977, 'num_leaves': 110, 'max_depth': 12, 'min_child_samples': 75, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.23381489352162219, 'reg_lambda': 0.023931249313753785, 'min_split_gain': 0.4313293883992248, 'min_child_weight': 0.02314941032839009}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:23,409] Trial 34 finished with value: 0.8437107017350332 and parameters: {'n_estimators': 900, 'learning_rate': 0.00761756318033603, 'num_leaves': 160, 'max_depth': 14, 'min_child_samples': 60, 'subsample': 0.95, 'colsample_bytree': 1.0, 'reg_alpha': 0.7084058050733829, 'reg_lambda': 0.3074555797442693, 'min_split_gain': 0.21341171774394185, 'min_child_weight': 0.04587146318305066}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:23,931] Trial 35 finished with value: 0.8465133870179807 and parameters: {'n_estimators': 1000, 'learning_rate': 0.079704095868988, 'num_leaves': 190, 'max_depth': 9, 'min_child_samples': 50, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_alpha': 0.2078497369737572, 'reg_lambda': 18.434682378402027, 'min_split_gain': 0.3812318828939135, 'min_child_weight': 0.4605653401905018}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:24,730] Trial 36 finished with value: 0.8470747908032212 and parameters: {'n_estimators': 700, 'learning_rate': 0.03011025117420547, 'num_leaves': 110, 'max_depth': 14, 'min_child_samples': 65, 'subsample': 0.95, 'colsample_bytree': 0.45, 'reg_alpha': 0.0011427418841149222, 'reg_lambda': 0.17621141379178948, 'min_split_gain': 0.6520700969040344, 'min_child_weight': 0.006444755501297961}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:25,534] Trial 37 finished with value: 0.8442827426446253 and parameters: {'n_estimators': 500, 'learning_rate': 0.03072664572677869, 'num_leaves': 110, 'max_depth': 14, 'min_child_samples': 75, 'subsample': 1.0, 'colsample_bytree': 0.45, 'reg_alpha': 0.0016607837618185033, 'reg_lambda': 0.008297647415308943, 'min_split_gain': 0.6336903135991702, 'min_child_weight': 0.006113244091960173}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:26,123] Trial 38 finished with value: 0.8445526104291095 and parameters: {'n_estimators': 200, 'learning_rate': 0.021737922214226386, 'num_leaves': 90, 'max_depth': 15, 'min_child_samples': 70, 'subsample': 0.95, 'colsample_bytree': 0.45, 'reg_alpha': 0.003566726984314991, 'reg_lambda': 9.760475926529619, 'min_split_gain': 0.6557387191491167, 'min_child_weight': 0.009274333389258517}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:26,796] Trial 39 finished with value: 0.8473584474526057 and parameters: {'n_estimators': 400, 'learning_rate': 0.05321383519516386, 'num_leaves': 130, 'max_depth': 13, 'min_child_samples': 85, 'subsample': 1.0, 'colsample_bytree': 0.5, 'reg_alpha': 0.005304506677466269, 'reg_lambda': 0.6586402284853695, 'min_split_gain': 0.5352884802208098, 'min_child_weight': 0.002987768121809363}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:29,448] Trial 40 finished with value: 0.8434349244370203 and parameters: {'n_estimators': 200, 'learning_rate': 0.05406320977415188, 'num_leaves': 130, 'max_depth': 13, 'min_child_samples': 85, 'subsample': 0.7, 'colsample_bytree': 0.55, 'reg_alpha': 0.003697468892006714, 'reg_lambda': 0.7376031217959216, 'min_split_gain': 0.5660158972870617, 'min_child_weight': 0.003055603750930507}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:30,286] Trial 41 finished with value: 0.8465181146288039 and parameters: {'n_estimators': 400, 'learning_rate': 0.02899972254887912, 'num_leaves': 100, 'max_depth': 14, 'min_child_samples': 90, 'subsample': 1.0, 'colsample_bytree': 0.5, 'reg_alpha': 0.001014419639049454, 'reg_lambda': 0.18893995512763162, 'min_split_gain': 0.5062303488400254, 'min_child_weight': 0.0016086242156515085}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:30,800] Trial 42 finished with value: 0.846243125265928 and parameters: {'n_estimators': 400, 'learning_rate': 0.053543766613378826, 'num_leaves': 120, 'max_depth': 12, 'min_child_samples': 85, 'subsample': 0.95, 'colsample_bytree': 0.45, 'reg_alpha': 0.003960407472733657, 'reg_lambda': 0.07247077348915562, 'min_split_gain': 0.5953405058420421, 'min_child_weight': 0.0039057640912962834}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:31,625] Trial 43 finished with value: 0.8451207116630159 and parameters: {'n_estimators': 600, 'learning_rate': 0.03453135130892804, 'num_leaves': 90, 'max_depth': 13, 'min_child_samples': 65, 'subsample': 1.0, 'colsample_bytree': 0.4, 'reg_alpha': 0.0010247394903016673, 'reg_lambda': 1.3765959114681887, 'min_split_gain': 0.6637521094339355, 'min_child_weight': 0.00888305850736681}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:32,830] Trial 44 finished with value: 0.8468013773106199 and parameters: {'n_estimators': 800, 'learning_rate': 0.017939961067175325, 'num_leaves': 110, 'max_depth': 15, 'min_child_samples': 75, 'subsample': 0.95, 'colsample_bytree': 0.5, 'reg_alpha': 0.017829404791286994, 'reg_lambda': 2.6919879443608465, 'min_split_gain': 0.5335018452395756, 'min_child_weight': 0.013052386912114541}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:33,675] Trial 45 finished with value: 0.8439916006114376 and parameters: {'n_estimators': 300, 'learning_rate': 0.024349170717243126, 'num_leaves': 140, 'max_depth': 14, 'min_child_samples': 60, 'subsample': 1.0, 'colsample_bytree': 0.55, 'reg_alpha': 0.006027232024706434, 'reg_lambda': 0.4845196671141423, 'min_split_gain': 0.4637663851298564, 'min_child_weight': 0.001189407488595271}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:34,398] Trial 46 finished with value: 0.8473596293553115 and parameters: {'n_estimators': 500, 'learning_rate': 0.03836043727133159, 'num_leaves': 70, 'max_depth': 8, 'min_child_samples': 45, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0.0016237275218193444, 'reg_lambda': 12.816632796590948, 'min_split_gain': 0.6877618990543648, 'min_child_weight': 0.00039576249129814265}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:34,974] Trial 47 finished with value: 0.8459602565516807 and parameters: {'n_estimators': 300, 'learning_rate': 0.04128152078914152, 'num_leaves': 70, 'max_depth': 8, 'min_child_samples': 45, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.0024191805453720274, 'reg_lambda': 4.469134050294405, 'min_split_gain': 0.696711384380585, 'min_child_weight': 0.00011100329281491441}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:35,431] Trial 48 finished with value: 0.8453949130907544 and parameters: {'n_estimators': 500, 'learning_rate': 0.07290908508031425, 'num_leaves': 60, 'max_depth': 7, 'min_child_samples': 45, 'subsample': 0.55, 'colsample_bytree': 0.65, 'reg_alpha': 2.382145399483903, 'reg_lambda': 12.49413851156606, 'min_split_gain': 0.42588681405685425, 'min_child_weight': 0.0003712348313993563}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:35,989] Trial 49 finished with value: 0.8470751847707897 and parameters: {'n_estimators': 1500, 'learning_rate': 0.05555850583358403, 'num_leaves': 70, 'max_depth': 9, 'min_child_samples': 40, 'subsample': 0.6, 'colsample_bytree': 0.5, 'reg_alpha': 0.013730705992294904, 'reg_lambda': 7.92775625812553, 'min_split_gain': 0.4590603275753732, 'min_child_weight': 0.0003543528691172147}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:36,800] Trial 50 finished with value: 0.8470826701545928 and parameters: {'n_estimators': 1900, 'learning_rate': 0.03647707262660405, 'num_leaves': 130, 'max_depth': 7, 'min_child_samples': 20, 'subsample': 0.65, 'colsample_bytree': 0.55, 'reg_alpha': 4.541521696122336, 'reg_lambda': 19.96719287446391, 'min_split_gain': 0.4157168689870627, 'min_child_weight': 0.1198628112609937}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:37,563] Trial 51 finished with value: 0.8437114896701704 and parameters: {'n_estimators': 2000, 'learning_rate': 0.03344527925055241, 'num_leaves': 130, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.65, 'colsample_bytree': 0.55, 'reg_alpha': 9.875140130603205, 'reg_lambda': 17.91263067495496, 'min_split_gain': 0.40685354964332987, 'min_child_weight': 0.0002077025265105133}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:38,276] Trial 52 finished with value: 0.8476428920371275 and parameters: {'n_estimators': 1900, 'learning_rate': 0.040719879127847254, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 25, 'subsample': 0.7, 'colsample_bytree': 0.55, 'reg_alpha': 1.8071339349188402, 'reg_lambda': 11.284125932819157, 'min_split_gain': 0.3686040296814539, 'min_child_weight': 0.10490903528651993}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:38,875] Trial 53 finished with value: 0.848483618828498 and parameters: {'n_estimators': 1800, 'learning_rate': 0.049226914957149856, 'num_leaves': 90, 'max_depth': 5, 'min_child_samples': 15, 'subsample': 0.55, 'colsample_bytree': 0.5, 'reg_alpha': 1.701020608141375, 'reg_lambda': 4.970497943378091, 'min_split_gain': 0.30158697522935407, 'min_child_weight': 0.045010070175394774}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:43,741] Trial 54 finished with value: 0.8423066013205792 and parameters: {'n_estimators': 1800, 'learning_rate': 0.007766428499467721, 'num_leaves': 90, 'max_depth': 5, 'min_child_samples': 15, 'subsample': 0.55, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.6896269113489373, 'reg_lambda': 5.3197141871420435, 'min_split_gain': 0.2955355575803925, 'min_child_weight': 0.04439615727809129}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:44,377] Trial 55 finished with value: 0.8476468317128134 and parameters: {'n_estimators': 1700, 'learning_rate': 0.04384958850054976, 'num_leaves': 80, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.55, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.35662350128326425, 'reg_lambda': 12.002549842387687, 'min_split_gain': 0.35555922450848165, 'min_child_weight': 0.1351165568221405}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:44,967] Trial 56 finished with value: 0.8482082354980538 and parameters: {'n_estimators': 1700, 'learning_rate': 0.04793562061140403, 'num_leaves': 80, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.7, 'colsample_bytree': 0.65, 'reg_alpha': 0.4948003255240816, 'reg_lambda': 3.8101906758665818, 'min_split_gain': 0.3651454740626283, 'min_child_weight': 0.13139419603190705}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:45,540] Trial 57 finished with value: 0.8459582867138377 and parameters: {'n_estimators': 1700, 'learning_rate': 0.047020790372107935, 'num_leaves': 80, 'max_depth': 4, 'min_child_samples': 30, 'subsample': 0.7, 'colsample_bytree': 0.65, 'reg_alpha': 0.4410210728240285, 'reg_lambda': 3.4932066240085184, 'min_split_gain': 0.36443296205028014, 'min_child_weight': 0.3500549192402106}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:46,026] Trial 58 finished with value: 0.845114802149487 and parameters: {'n_estimators': 1900, 'learning_rate': 0.06340694131373495, 'num_leaves': 60, 'max_depth': 3, 'min_child_samples': 20, 'subsample': 0.75, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.9165381254593294, 'reg_lambda': 7.065702610514164, 'min_split_gain': 0.31189695114951504, 'min_child_weight': 0.06733697716761013}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:46,868] Trial 59 finished with value: 0.8465157508233923 and parameters: {'n_estimators': 1700, 'learning_rate': 0.026755882784122616, 'num_leaves': 100, 'max_depth': 4, 'min_child_samples': 30, 'subsample': 0.55, 'colsample_bytree': 0.65, 'reg_alpha': 0.3403574652938306, 'reg_lambda': 2.573538564338003, 'min_split_gain': 0.2761105865061981, 'min_child_weight': 0.1568771850071643}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:47,453] Trial 60 finished with value: 0.841747955308319 and parameters: {'n_estimators': 1900, 'learning_rate': 0.04803957880660466, 'num_leaves': 90, 'max_depth': 5, 'min_child_samples': 10, 'subsample': 0.6, 'colsample_bytree': 0.7000000000000001, 'reg_alpha': 0.5423895502050645, 'reg_lambda': 10.749580781857059, 'min_split_gain': 0.2383110078196787, 'min_child_weight': 0.2911378257648108}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:48,031] Trial 61 finished with value: 0.8417483492758876 and parameters: {'n_estimators': 1600, 'learning_rate': 0.04538628982729374, 'num_leaves': 100, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.7, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.9325162142422136, 'reg_lambda': 4.1998975897707, 'min_split_gain': 0.3541682115264694, 'min_child_weight': 0.6558240660948096}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:48,524] Trial 62 finished with value: 0.8437138534755819 and parameters: {'n_estimators': 1800, 'learning_rate': 0.0593678897225174, 'num_leaves': 80, 'max_depth': 5, 'min_child_samples': 15, 'subsample': 0.65, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.848831730437507, 'reg_lambda': 7.725062911090104, 'min_split_gain': 0.33326950614277373, 'min_child_weight': 0.100809772013858}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:49,184] Trial 63 finished with value: 0.8451179538900357 and parameters: {'n_estimators': 1600, 'learning_rate': 0.04203798312940068, 'num_leaves': 80, 'max_depth': 6, 'min_child_samples': 20, 'subsample': 0.55, 'colsample_bytree': 0.75, 'reg_alpha': 3.539065054291061, 'reg_lambda': 13.390703981411828, 'min_split_gain': 0.3785407394960323, 'min_child_weight': 0.032796319978530566}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:51,478] Trial 64 finished with value: 0.8462380036875364 and parameters: {'n_estimators': 1900, 'learning_rate': 0.011238831552444463, 'num_leaves': 50, 'max_depth': 3, 'min_child_samples': 35, 'subsample': 0.75, 'colsample_bytree': 0.55, 'reg_alpha': 0.36251671320850715, 'reg_lambda': 2.136142820786288, 'min_split_gain': 0.48460634333990055, 'min_child_weight': 0.06611675719813345}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:56,096] Trial 65 finished with value: 0.8465228422396267 and parameters: {'n_estimators': 1400, 'learning_rate': 0.008735365740223737, 'num_leaves': 90, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.7, 'colsample_bytree': 0.65, 'reg_alpha': 1.087624295493214, 'reg_lambda': 6.63244877821684, 'min_split_gain': 0.45039391881747687, 'min_child_weight': 0.16558664510439128}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:44:59,494] Trial 66 finished with value: 0.8420260964117434 and parameters: {'n_estimators': 2000, 'learning_rate': 0.006208406298927841, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 10, 'subsample': 0.6, 'colsample_bytree': 0.7000000000000001, 'reg_alpha': 0.1564843458297437, 'reg_lambda': 9.326110653879999, 'min_split_gain': 0.3383319621291883, 'min_child_weight': 0.1346885324771146}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:00,521] Trial 67 finished with value: 0.843438076177569 and parameters: {'n_estimators': 1700, 'learning_rate': 0.021416984680309302, 'num_leaves': 110, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_alpha': 1.7653088735590596, 'reg_lambda': 1.0408888262793956, 'min_split_gain': 0.3107132954368256, 'min_child_weight': 0.08978302554911666}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:00,887] Trial 68 finished with value: 0.8425902579699638 and parameters: {'n_estimators': 1800, 'learning_rate': 0.11309597441872458, 'num_leaves': 120, 'max_depth': 11, 'min_child_samples': 35, 'subsample': 0.65, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.05503746772423994, 'reg_lambda': 14.96419653759039, 'min_split_gain': 0.40102815532268304, 'min_child_weight': 0.22198924345649976}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:02,283] Trial 69 finished with value: 0.8465220543044897 and parameters: {'n_estimators': 1500, 'learning_rate': 0.014814039177253683, 'num_leaves': 70, 'max_depth': 10, 'min_child_samples': 5, 'subsample': 0.6, 'colsample_bytree': 0.75, 'reg_alpha': 0.5711988356992048, 'reg_lambda': 4.452072022884594, 'min_split_gain': 0.4774202727240938, 'min_child_weight': 0.06001053048044043}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:02,749] Trial 70 finished with value: 0.8456793576752762 and parameters: {'n_estimators': 1300, 'learning_rate': 0.07132197835605292, 'num_leaves': 80, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.55, 'colsample_bytree': 0.9, 'reg_alpha': 0.0975706588237163, 'reg_lambda': 3.389746174569954, 'min_split_gain': 0.3673819394334877, 'min_child_weight': 0.031663846019741045}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:03,734] Trial 71 finished with value: 0.844553004396678 and parameters: {'n_estimators': 1600, 'learning_rate': 0.0374552045277677, 'num_leaves': 70, 'max_depth': 5, 'min_child_samples': 55, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0.2927167517444598, 'reg_lambda': 12.48341538124278, 'min_split_gain': 0.16109210003677416, 'min_child_weight': 0.29863045246256026}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:07,017] Trial 72 finished with value: 0.8479245788486691 and parameters: {'n_estimators': 1900, 'learning_rate': 0.03283536440665687, 'num_leaves': 90, 'max_depth': 6, 'min_child_samples': 30, 'subsample': 0.5, 'colsample_bytree': 0.55, 'reg_alpha': 0.7703328809565465, 'reg_lambda': 10.056407362048667, 'min_split_gain': 0.21388437128142906, 'min_child_weight': 0.1110189234616047}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:07,715] Trial 73 finished with value: 0.8437173991836993 and parameters: {'n_estimators': 1900, 'learning_rate': 0.04953706854150644, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 15, 'subsample': 0.75, 'colsample_bytree': 0.55, 'reg_alpha': 0.7577115021985777, 'reg_lambda': 5.754232657961535, 'min_split_gain': 0.08601149635197147, 'min_child_weight': 0.10797497990712351}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:08,456] Trial 74 finished with value: 0.8425902579699638 and parameters: {'n_estimators': 2000, 'learning_rate': 0.03187773180967624, 'num_leaves': 90, 'max_depth': 3, 'min_child_samples': 30, 'subsample': 0.5, 'colsample_bytree': 0.65, 'reg_alpha': 1.253969036014969, 'reg_lambda': 1.6245220206494069, 'min_split_gain': 0.19803400608088267, 'min_child_weight': 0.9906534521075101}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:09,438] Trial 75 finished with value: 0.8445577320075012 and parameters: {'n_estimators': 1700, 'learning_rate': 0.02571387661091448, 'num_leaves': 110, 'max_depth': 11, 'min_child_samples': 35, 'subsample': 0.55, 'colsample_bytree': 0.9500000000000001, 'reg_alpha': 0.03219207364707432, 'reg_lambda': 8.853748987682199, 'min_split_gain': 0.2524021336183279, 'min_child_weight': 0.1902081639039229}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:10,204] Trial 76 finished with value: 0.8462387916226737 and parameters: {'n_estimators': 1800, 'learning_rate': 0.042264655417762156, 'num_leaves': 90, 'max_depth': 6, 'min_child_samples': 70, 'subsample': 0.8500000000000001, 'colsample_bytree': 0.55, 'reg_alpha': 2.3998378343482596, 'reg_lambda': 19.598986070780754, 'min_split_gain': 0.2813984235022098, 'min_child_weight': 0.05265821583807027}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:10,597] Trial 77 finished with value: 0.8437130655404449 and parameters: {'n_estimators': 1800, 'learning_rate': 0.09499170474491665, 'num_leaves': 60, 'max_depth': 5, 'min_child_samples': 40, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.16714376416467494, 'reg_lambda': 10.449366403945803, 'min_split_gain': 0.43076689473174773, 'min_child_weight': 0.08227667540351628}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:12,289] Trial 78 finished with value: 0.843995146319555 and parameters: {'n_estimators': 1900, 'learning_rate': 0.01654034981035238, 'num_leaves': 120, 'max_depth': 10, 'min_child_samples': 80, 'subsample': 0.7, 'colsample_bytree': 0.55, 'reg_alpha': 0.5481643932471042, 'reg_lambda': 5.712381112097423, 'min_split_gain': 0.11452946156481256, 'min_child_weight': 0.4828404810301944}. Best is trial 23 with value: 0.8490458105488756.
# [I 2025-05-12 23:45:12,785] Trial 79 finished with value: 0.8504538506390155 and parameters: {'n_estimators': 1100, 'learning_rate': 0.06509228494862056, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 25, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.5671157141467156, 'reg_lambda': 14.655960291115573, 'min_split_gain': 0.3854595582770911, 'min_child_weight': 0.1393188921160219}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:13,215] Trial 80 finished with value: 0.8462395795578107 and parameters: {'n_estimators': 1100, 'learning_rate': 0.08206210182593847, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 25, 'subsample': 0.5, 'colsample_bytree': 0.65, 'reg_alpha': 3.8616859277688893, 'reg_lambda': 14.864616538840417, 'min_split_gain': 0.3934399693361531, 'min_child_weight': 0.12868946405158602}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:13,713] Trial 81 finished with value: 0.841754652756985 and parameters: {'n_estimators': 1200, 'learning_rate': 0.06380496216600637, 'num_leaves': 100, 'max_depth': 12, 'min_child_samples': 25, 'subsample': 0.55, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.5118236765223145, 'reg_lambda': 11.465315532510182, 'min_split_gain': 0.37435011056733464, 'min_child_weight': 0.1663281222107373}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:14,579] Trial 82 finished with value: 0.841747955308319 and parameters: {'n_estimators': 1300, 'learning_rate': 0.028862237869919014, 'num_leaves': 110, 'max_depth': 11, 'min_child_samples': 30, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.8786286039357264, 'reg_lambda': 7.926459005016557, 'min_split_gain': 0.3500178403406609, 'min_child_weight': 0.26888014852272857}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:15,172] Trial 83 finished with value: 0.8434384701451376 and parameters: {'n_estimators': 1100, 'learning_rate': 0.05077681712884815, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 15, 'subsample': 0.5, 'colsample_bytree': 0.55, 'reg_alpha': 7.268990519331866, 'reg_lambda': 15.820596716813291, 'min_split_gain': 0.43478660258019025, 'min_child_weight': 0.08151160319664236}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:15,746] Trial 84 finished with value: 0.8442835305797628 and parameters: {'n_estimators': 900, 'learning_rate': 0.057891502315312766, 'num_leaves': 90, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6, 'colsample_bytree': 1.0, 'reg_alpha': 2.0328959558266573, 'reg_lambda': 4.543832503713339, 'min_split_gain': 0.4169200122019671, 'min_child_weight': 0.2149043408836145}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:16,109] Trial 85 finished with value: 0.8468033471484627 and parameters: {'n_estimators': 1700, 'learning_rate': 0.13259596638179186, 'num_leaves': 100, 'max_depth': 11, 'min_child_samples': 75, 'subsample': 0.55, 'colsample_bytree': 0.65, 'reg_alpha': 1.0978974826893733, 'reg_lambda': 6.7779287823504175, 'min_split_gain': 0.3215962836873745, 'min_child_weight': 0.0343872861627956}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:16,781] Trial 86 finished with value: 0.845953165135446 and parameters: {'n_estimators': 2000, 'learning_rate': 0.04463994636665743, 'num_leaves': 70, 'max_depth': 10, 'min_child_samples': 10, 'subsample': 0.95, 'colsample_bytree': 0.5, 'reg_alpha': 0.413857641656393, 'reg_lambda': 9.582688478154054, 'min_split_gain': 0.386992906391158, 'min_child_weight': 0.14522772028921885}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:19,764] Trial 87 finished with value: 0.8437126715728761 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03864836282629496, 'num_leaves': 80, 'max_depth': 6, 'min_child_samples': 70, 'subsample': 0.75, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.6644375131867601, 'reg_lambda': 0.017188765632547447, 'min_split_gain': 0.215698056984222, 'min_child_weight': 0.09531698340633016}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:20,534] Trial 88 finished with value: 0.8451191357927416 and parameters: {'n_estimators': 1800, 'learning_rate': 0.03515079497511473, 'num_leaves': 90, 'max_depth': 8, 'min_child_samples': 35, 'subsample': 0.9, 'colsample_bytree': 0.55, 'reg_alpha': 2.788110309720464, 'reg_lambda': 15.01291984879926, 'min_split_gain': 0.5178009381838546, 'min_child_weight': 0.3842883965553995}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:21,458] Trial 89 finished with value: 0.845678569740139 and parameters: {'n_estimators': 1900, 'learning_rate': 0.03176377674462448, 'num_leaves': 40, 'max_depth': 9, 'min_child_samples': 20, 'subsample': 0.5, 'colsample_bytree': 0.65, 'reg_alpha': 0.2622913093085545, 'reg_lambda': 11.184010070101909, 'min_split_gain': 0.29728543239315675, 'min_child_weight': 0.11706610850075476}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:21,896] Trial 90 finished with value: 0.8451234694359959 and parameters: {'n_estimators': 800, 'learning_rate': 0.07690140587811715, 'num_leaves': 100, 'max_depth': 4, 'min_child_samples': 60, 'subsample': 0.8, 'colsample_bytree': 0.5, 'reg_alpha': 1.4087113646371296, 'reg_lambda': 0.0018729726083386534, 'min_split_gain': 0.40734312023884267, 'min_child_weight': 0.015107956471671355}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:22,631] Trial 91 finished with value: 0.8439963282222607 and parameters: {'n_estimators': 600, 'learning_rate': 0.039365461364695965, 'num_leaves': 70, 'max_depth': 13, 'min_child_samples': 40, 'subsample': 0.5, 'colsample_bytree': 0.5, 'reg_alpha': 0.8311305787344198, 'reg_lambda': 13.003158245166059, 'min_split_gain': 0.3476281672215106, 'min_child_weight': 0.056769239024521}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:23,169] Trial 92 finished with value: 0.847638558393873 and parameters: {'n_estimators': 2000, 'learning_rate': 0.06700197252326322, 'num_leaves': 70, 'max_depth': 7, 'min_child_samples': 50, 'subsample': 0.5, 'colsample_bytree': 0.45, 'reg_alpha': 0.47320068726079456, 'reg_lambda': 19.480412289664713, 'min_split_gain': 0.47044499374391696, 'min_child_weight': 0.0006586099052693063}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:23,672] Trial 93 finished with value: 0.844271711552705 and parameters: {'n_estimators': 2000, 'learning_rate': 0.08935307215970292, 'num_leaves': 60, 'max_depth': 7, 'min_child_samples': 50, 'subsample': 0.55, 'colsample_bytree': 0.4, 'reg_alpha': 0.5199553243071645, 'reg_lambda': 19.269449286846278, 'min_split_gain': 0.46994084886607457, 'min_child_weight': 0.0022239550526222934}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:24,030] Trial 94 finished with value: 0.8451151961170555 and parameters: {'n_estimators': 1900, 'learning_rate': 0.10054818743931888, 'num_leaves': 80, 'max_depth': 5, 'min_child_samples': 30, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 0.32640868766236436, 'reg_lambda': 6.210803753160721, 'min_split_gain': 0.4452346866541543, 'min_child_weight': 0.07008816623856212}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:24,533] Trial 95 finished with value: 0.8445490647209921 and parameters: {'n_estimators': 2000, 'learning_rate': 0.06682919624659502, 'num_leaves': 50, 'max_depth': 6, 'min_child_samples': 65, 'subsample': 0.55, 'colsample_bytree': 0.45, 'reg_alpha': 1.065212216994861, 'reg_lambda': 3.865148743123337, 'min_split_gain': 0.45215318821565786, 'min_child_weight': 0.19646180937366}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:24,855] Trial 96 finished with value: 0.8473675087066832 and parameters: {'n_estimators': 1800, 'learning_rate': 0.14951410930980008, 'num_leaves': 120, 'max_depth': 5, 'min_child_samples': 70, 'subsample': 1.0, 'colsample_bytree': 0.45, 'reg_alpha': 0.2166856200583803, 'reg_lambda': 9.039192485256313, 'min_split_gain': 0.4938332977490475, 'min_child_weight': 0.0007051217757351852}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:25,192] Trial 97 finished with value: 0.8425938036780811 and parameters: {'n_estimators': 1800, 'learning_rate': 0.14525849073215166, 'num_leaves': 120, 'max_depth': 5, 'min_child_samples': 80, 'subsample': 1.0, 'colsample_bytree': 0.45, 'reg_alpha': 0.18205887623816586, 'reg_lambda': 8.902931292970742, 'min_split_gain': 0.5587524215031981, 'min_child_weight': 0.0010087515955125418}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:25,599] Trial 98 finished with value: 0.8453968829285973 and parameters: {'n_estimators': 1100, 'learning_rate': 0.10284692618350418, 'num_leaves': 90, 'max_depth': 7, 'min_child_samples': 25, 'subsample': 1.0, 'colsample_bytree': 0.45, 'reg_alpha': 0.22963199113414964, 'reg_lambda': 5.178229462307859, 'min_split_gain': 0.5097929515720249, 'min_child_weight': 0.0005125509088163943}. Best is trial 79 with value: 0.8504538506390155.
# [I 2025-05-12 23:45:25,984] Trial 99 finished with value: 0.8467986195376398 and parameters: {'n_estimators': 1700, 'learning_rate': 0.1255097180221533, 'num_leaves': 80, 'max_depth': 6, 'min_child_samples': 30, 'subsample': 0.5, 'colsample_bytree': 0.4, 'reg_alpha': 0.13367043564582215, 'reg_lambda': 2.628634448098069, 'min_split_gain': 0.49777524361814895, 'min_child_weight': 0.0005599153065823321}. Best is trial 79 with value: 0.8504538506390155.
# Otimização com Optuna concluída!
# Melhor Acurácia Média no CV/Val do Optuna: 0.8505
# Melhores hiperparâmetros (Optuna): {'n_estimators': 1100, 'learning_rate': 0.06509228494862056, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 25, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.5671157141467156, 'reg_lambda': 14.655960291115573, 'min_split_gain': 0.3854595582770911, 'min_child_weight': 0.1393188921160219}
# Treinando o modelo final com early stopping...
# Modelo final treinado. Número de árvores: 105
# Acurácia do Modelo Final no seu Conjunto de Treinamento (X_train_final): 0.8583
#
# Avaliando o modelo final no conjunto de teste (com features selecionadas)...
#
# --- Resultados da Avaliação no CONJUNTO DE TESTE (v7 - Final - Binário) ---
# Acurácia no Teste: 0.8335
# Precisão Média (Macro Avg) no Teste: 0.8331
# Precisão Média (Weighted Avg) no Teste: 0.8335
# F1-Score (Ponderado) no Teste: 0.8335
# ROC AUC (Binário) no Teste: 0.9234
#
# Relatório de Classificação (Teste):
#                 precision    recall  f1-score   support
#
#  Salário Alto       0.84      0.84      0.84       622
# Salário Baixo       0.83      0.83      0.83       567
#
#      accuracy                           0.83      1189
#     macro avg       0.83      0.83      0.83      1189
#  weighted avg       0.83      0.83      0.83      1189
# Importância das Features (após RFECV, modelo Optuna com ES):
#              feature  importance
# 2              P2_i         179
# 4  P2_f_Cargo_Atual         157
# 3        P2_g_Nivel         144
# 1              P1_l          97
# 0            P1_a_1          94
# 5    Regiao_Mapeada          66
# Modelo e metadados salvos em modelo_lgbm_classificacao_faixa_salarial_v7_final_rfecv.pkl
#
#
# --- Resumo Final da Execução (v7 - Final com RFECV, Optuna, ES) ---
# Tipo de Classificação: Binário, Classes: ['Salário Alto', 'Salário Baixo']
# Acurácia do Modelo Final no Treinamento (X_train_final): 0.8583
# Acurácia Média CV/Val (Optuna): 0.8505
# -------------------------------------------------------------
# Acurácia no Teste: 0.8335
# Precisão Média (Macro Avg) no Teste: 0.8331
# Precisão Média (Weighted Avg) no Teste: 0.8335
# F1-Score (Ponderado) no Teste: 0.8335
# ROC AUC (Binário) no Teste: 0.9234
# -------------------------------------------------------------
# Features Selecionadas pelo RFECV: 6 -> ['P1_a_1', 'P1_l', 'P2_i', 'P2_g_Nivel', 'P2_f_Cargo_Atual', 'Regiao_Mapeada']
# Melhores Parâmetros (Optuna): {'n_estimators': 1100, 'learning_rate': 0.06509228494862056, 'num_leaves': 80, 'max_depth': 12, 'min_child_samples': 25, 'subsample': 0.5, 'colsample_bytree': 0.6000000000000001, 'reg_alpha': 1.5671157141467156, 'reg_lambda': 14.655960291115573, 'min_split_gain': 0.3854595582770911, 'min_child_weight': 0.1393188921160219}
# Número de Árvores no Modelo Final: 105
# Modelo e resultados detalhados salvos em arquivos.
